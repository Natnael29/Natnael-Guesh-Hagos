# %% [markdown]
# <a href="https://colab.research.google.com/github/Natnael29/Natnael-Guesh-Hagos/blob/main/Import_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Try to handle errors by skipping bad lines
df = pd.read_csv("Archiv_2024_9_16_7.csv", on_bad_lines='skip', sep=';')  # Added sep=';'

df = pd.read_csv("Archiv_2024_9_16_7.csv", sep=';')


print(df.to_string())
# Out:
#     Prozesszeit Nahtposition Axialkraft_SOLL Axialkraft_IST Drehmoment_IST Z-Schulterposition Bahnvorschub      Drehzahl Spindelmoment Vorschubkraft  Seitenkraft Komponentenkraft X+ Komponentenkraft Y+ Komponentenkraft X- Komponentenkraft Y-
# 0          [ms]         [mm]             [N]            [N]           [Nm]               [mm]     [mm/min]       [1/Min]          [Nm]           [N]          [N]                 [N]                 [N]                 [N]                 [N]
# 1             0            0               0              0              0                  0            0  -731,1058044             0   86,92413393  14,59083677                   0                   0                   0                   0
# 2           100            0            3400    26,62037037       1,16E-02                  0            0  -1999,225616        -0,658   86,92413393  14,59083677                   0                   0                   0                   0
# ...
